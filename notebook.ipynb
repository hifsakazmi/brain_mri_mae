# %% [markdown]
# <a href="https://colab.research.google.com/github/hifsakazmi/brain_mri_mae/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CONNECT TO GOOGLE DRIVE

from google.colab import drive
drive.mount('/content/drive')

# %%
# CLONE GITHUB REPO
# !rm -rf mri_mae_project
# !git clone https://github.com/hifsakazmi/brain_mri_mae.git brain_mri_mae

# %cd brain_mri_mae

# %%
# INSTALL DEPENDENCIES
# !pip install timm torch torchvision einops albumentations

# %%
# PULL LATEST CHANGES
# !git pull

# %%
# RUN MAE PRETRAINING
# !python run_pretrain.py --config config.py

# %%
# RUN CLASSIFICATION FINE-TUNING
# !python run_finetune.py --config config.py
